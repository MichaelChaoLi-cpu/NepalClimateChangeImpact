# %% [markdown]
# # Build the experiment for Education

# %%
import os, sys

sys.path.append(os.path.abspath("."))

# %%
os.chdir(CURRENT_ADDR := os.path.abspath(".."))

# %%
print(CURRENT_ADDR)
# Out:
# /Users/lichao/Library/CloudStorage/OneDrive-Personal/MLD01_Article

# %% [markdown]
# ## Import Package

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from xgboost import XGBClassifier

# %%
from LoadDataFromDisk import load_data_from_disk
from KnowledgeRelatedDataProcess import make_data_for_knowledge_related_analysis
from CounterandFacutalPrediction import predicting_counter_and_factual_knowledge_based_xgboost

# %% [markdown]
# ## Function

# %% [markdown]
# ## Run

# %%
if __name__ == '__main__':
    pass

# %%
df_all = load_data_from_disk()

# %%
df_for_knowledge = make_data_for_knowledge_related_analysis(
    df_all = df_all
    )

# %%
(
    factual_knowledge_probs, 
    counterfactual_knowledge_probs
    ) = predicting_counter_and_factual_knowledge_based_xgboost(
        df_for_knowledge = df_for_knowledge
        )
