# %% [markdown]
# # Build the experiment for Education

# %%
import os, sys

sys.path.append(os.path.abspath("."))

# %%
os.chdir(CURRENT_ADDR := os.path.abspath(".."))

# %%
print(CURRENT_ADDR)
# Out:
# /Users/lichao/Library/CloudStorage/OneDrive-Personal/MLD01_Article

# %% [markdown]
# ## Import Package

# %%
from LoadDataFromDisk import load_data_from_disk
from RelevantDataProcess import make_data_for_knowledge_related_analysis 
from RelevantDataProcess import make_data_for_awareness_related_analysis
from RelevantDataProcess import make_data_for_action_related_analysis
from CounterandFacutalPrediction import predicting_counter_and_factual_knowledge_based_xgboost
from CounterandFacutalPrediction import predicting_counter_and_factual_awareness_based_xgboost
from CounterandFacutalPrediction import predicting_counter_and_factual_action_based_xgboost

# %% [markdown]
# ## Function

# %% [markdown]
# ## Run

# %%
if __name__ == '__main__':
    pass

# %%
df_all = load_data_from_disk()

# %%
df_for_knowledge = make_data_for_knowledge_related_analysis(
    df_all = df_all
    )

# %%
(
    factual_knowledge_probs, 
    counterfactual_knowledge_probs
    ) = predicting_counter_and_factual_knowledge_based_xgboost(
        df_inuse = df_for_knowledge
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
os.makedirs(MLD01e1_RESULTS_ADDR := './MLD01e_Results/MLD01e1_Results/direct', exist_ok=True)

# %%
factual_knowledge_probs.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_knowledge_probs.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_knowledge_probs.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_knowledge_probs.parquet')
    )

# %%
df_for_awareness = make_data_for_awareness_related_analysis(
    df_all = df_all
)

# %%
(    
 factual_awareness_probs, 
 counterfactual_awareness_probs
    ) = predicting_counter_and_factual_awareness_based_xgboost(
        df_inuse = df_for_awareness,
        factural_knowledge_probs=factual_knowledge_probs[['mean']],
        counterfactual_knowledge_probs=counterfactual_knowledge_probs[['mean']],
        indirect_impact = False
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
factual_awareness_probs.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_awareness_probs.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_awareness_probs.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_awareness_probs.parquet')
    )

# %%
df_for_action = make_data_for_action_related_analysis(
    df_all = df_all,
    action_variable = (action_variable:='Soil and Water Conservation Measures in Past Dummy')
)

# %%
(    
 factual_action_probs_soilandwater, 
 counterfactual_action_probs_soilandwater
    ) = predicting_counter_and_factual_action_based_xgboost(
        df_inuse = df_for_action,
        factural_knowledge_probs=factual_knowledge_probs[['mean']],
        counterfactual_knowledge_probs=counterfactual_knowledge_probs[['mean']],
        factural_awareness_probs=factual_awareness_probs[['mean']],
        counterfactual_awareness_probs=counterfactual_awareness_probs[['mean']],
        action_type= action_variable,
        indirect_impact = False
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
factual_action_probs_soilandwater.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_action_probs_soilandwater.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_action_probs_soilandwater.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_action_probs_soilandwater.parquet')
    )

# %%
df_for_action = make_data_for_action_related_analysis(
    df_all = df_all,
    action_variable = (action_variable:='Risk Reduction Measurement in Past Dummy')
)

# %%
(    
 factual_action_probs_riskreduction, 
 counterfactual_action_probs_riskreduction
    ) = predicting_counter_and_factual_action_based_xgboost(
        df_inuse = df_for_action,
        factural_knowledge_probs=factual_knowledge_probs[['mean']],
        counterfactual_knowledge_probs=counterfactual_knowledge_probs[['mean']],
        factural_awareness_probs=factual_awareness_probs[['mean']],
        counterfactual_awareness_probs=counterfactual_awareness_probs[['mean']],
        action_type= action_variable,
        indirect_impact = False
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
factual_action_probs_riskreduction.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_action_probs_riskreduction.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_action_probs_riskreduction.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_action_probs_riskreduction.parquet')
    )

# %%
df_for_action = make_data_for_action_related_analysis(
    df_all = df_all,
    action_variable = (action_variable:='Road Improvement in Past Dummy')
)

# %%
(    
 factual_action_probs_roadimprovement, 
 counterfactual_action_probs_roadimprovement
    ) = predicting_counter_and_factual_action_based_xgboost(
        df_inuse = df_for_action,
        factural_knowledge_probs=factual_knowledge_probs[['mean']],
        counterfactual_knowledge_probs=counterfactual_knowledge_probs[['mean']],
        factural_awareness_probs=factual_awareness_probs[['mean']],
        counterfactual_awareness_probs=counterfactual_awareness_probs[['mean']],
        action_type= action_variable,
        indirect_impact = False
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
factual_action_probs_roadimprovement.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_action_probs_roadimprovement.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_action_probs_roadimprovement.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_action_probs_roadimprovement.parquet')
    )

# %%
df_for_action = make_data_for_action_related_analysis(
    df_all = df_all,
    action_variable = (action_variable:='Community Participation in Past Dummy')
)

# %%
(    
 factual_action_probs_communityparticipation, 
 counterfactual_action_probs_communityparticipation
    ) = predicting_counter_and_factual_action_based_xgboost(
        df_inuse = df_for_action,
        factural_knowledge_probs=factual_knowledge_probs[['mean']],
        counterfactual_knowledge_probs=counterfactual_knowledge_probs[['mean']],
        factural_awareness_probs=factual_awareness_probs[['mean']],
        counterfactual_awareness_probs=counterfactual_awareness_probs[['mean']],
        action_type= action_variable,
        indirect_impact = False
        )
# Out:
# epoch: 0, random_seed:42
# epoch: 1, random_seed:84
# epoch: 2, random_seed:126
# epoch: 3, random_seed:168
# epoch: 4, random_seed:210
# epoch: 5, random_seed:252
# epoch: 6, random_seed:294
# epoch: 7, random_seed:336
# epoch: 8, random_seed:378
# epoch: 9, random_seed:420

# %%
factual_action_probs_communityparticipation.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'factual_action_probs_communityparticipation.parquet')
    )
# Out:
# /Users/lichao/opt/anaconda3/envs/ML/lib/python3.9/site-packages/pandas/io/parquet.py:190: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
counterfactual_action_probs_communityparticipation.to_parquet(
    os.path.join(MLD01e1_RESULTS_ADDR, 'counterfactual_action_probs_communityparticipation.parquet')
    )
